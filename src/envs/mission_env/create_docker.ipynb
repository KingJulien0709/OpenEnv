# %%
# !docker build -t mission-env:latest --ssh default -f src/envs/mission_env/server/Dockerfile .
# Out:
# [+] Building 0.0s (0/0)                                          docker:default
# ERROR: failed to build: resolve : lstat src: no such file or directory

# %%
# !docker run -d -p 8000:8000 --name mission-env-container mission-env:latest

# %%
# !curl http://localhost:8000/health
